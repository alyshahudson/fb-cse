# %% [markdown]
# # Create Rule DataFrame

# %%
import pandas as pd
import re

rules_df = pd.read_csv('N-Grams Data.csv')

#removes previous index column and frequency of n-grams
rules_df = rules_df.drop(rules_df.columns[[0, 3]], axis = 1)

# %%
rules_df
# Out:
#                     Terms  Exceptions
# 0        the minimum wage         NaN
# 1             a great job         NaN
# 2              has done a         NaN
# 3              go back to         NaN
# 4                a lot of         NaN
# 5            vote for him         NaN
# 6            vote him out         NaN
# 7             he has done         NaN
# 8             needs to go         NaN
# 9              one of the         NaN
# 10           done a great         NaN
# 11       done a great job         NaN
# 12            to vote for         NaN
# 13            you want to         NaN
# 14             a good job         NaN
# 15            he needs to         NaN
# 16            sununu is a         NaN
# 17            the rest of         NaN
# 18        sununu has done         NaN
# 19       of new hampshire         NaN
# 20            is going to         NaN
# 21           dont want to         NaN
# 22            if you want         NaN
# 23       has done a great         NaN
# 24            you need to         NaN
# 25       in new hampshire         NaN
# 26   has done a great job         NaN
# 27             get rid of         NaN
# 28            if you dont         NaN
# 29             we need to         NaN
# ..                    ...         ...
# 400         you have said         NaN
# 401           care of the         NaN
# 402           to keep the         NaN
# 403          to deal with         NaN
# 404       red all the way         NaN
# 405          a better job         NaN
# 406            trump in a         NaN
# 407        gave himself a         NaN
# 408      sununu and trump         NaN
# 409         im not voting         NaN
# 410       you can request         NaN
# 411   i will not vote for         NaN
# 412        they dont want         NaN
# 413  in the united states         NaN
# 414             get a job         NaN
# 415           red all the         NaN
# 416          think he has         NaN
# 417  done a fantastic job         NaN
# 418       i will not vote         NaN
# 419         in the united         NaN
# 420     will not vote for         NaN
# 421       one of the best         NaN
# 422         and thats why         NaN
# 423           dont have a         NaN
# 424       to vote for him         NaN
# 425           did you get         NaN
# 426         to get rid of         NaN
# 427     going to vote for         NaN
# 428         no matter who         NaN
# 429         trump and the         NaN
#
# [430 rows x 2 columns]

# %% [markdown]
# # Train N-Grams on Labeled Data

# %%
users_df = pd.read_csv('Labeled.csv')
users_df = users_df.drop(users_df.columns[0], axis = 1)

#standardizes messages -- lowercase, removes whitespace characters and symbols
users_df['Message'] = users_df['Message'].apply(lambda x: x.lower())
users_df['Message'] = users_df['Message'].apply(lambda x: x.replace('nan', ''))
users_df['Message'] = users_df['Message'].apply(lambda x: re.sub(r'[^a-zA-Z0-9\s]', '', x))

# %%
users_df
# Out:
#                        Name  \
# 0      A Helmut Fickenwirth
# 1                 AJ Dupuis
# 2             Aaron Jackson
# 3           Aaron Krukowski
# 4              Aaron Robert
# 5               Ace Knowles
# 6             Adam Fontaine
# 7                Adam Jache
# 8             Adrienne Fran
# 9            Adrienne Spear
# 10      Afeez Azeez Ade-Ani
# 11               Al Cataldo
# 12                Al Coffey
# 13               Al Raymond
# 14               Al Woodard
# 15              Alan Canney
# 16               Alan Doyon
# 17            Alan Scoggins
# 18             Albert Bean-
# 19            Alden Nystrom
# 20              Alden Satas
# 21                Alex Kish
# 22   Alexandria Clendenning
# 23            Alfred Putney
# 24             Alice Landry
# 25         Alicia McNichols
# 26    Alison Friend LeBlanc
# 27          Alison Kay Rose
# 28             Alissa Souza
# 29            Allan Kennett
# ..                      ...
# 613               Tim Noyes
# 614           Tim Parenteau
# 615          Tim Pendergast
# 616              Tim Rigsby
# 617           Tim Schofield
# 618               Tim Wyatt
# 619             Timmy Hogan
# 620           Timothy Birch
# 621        Timothy C. White
# 622         Timothy Huckins
# 623           Timothy Minor
# 624             Tina Broyer
# 625          Tina Colangeli
# 626           Tina Lichtman
# 627           Tina Sabatini
# 628                Tj Speed
# 629            Toby A. Weir
# 630             Trevor Nash
# 631          Trisha O'Keefe
# 632      Trueliene Gaudette
# 633            Vic Chiasson
# 634            Vince Dimick
# 635         Virginia Norris
# 636        Walter P Sombric
# 637         William A Perry
# 638         William Clemons
# 639       William F. Condra
# 640           William Forte
# 641        William Matatall
# 642           Winston Grady
#
#                                                Message  Party_Affiliation
# 0                             gop   god s  own  party                   0
# 1    ahhhh i think you idiots have it backwards jus...                  0
# 2    considering the democrats started the kkk and ...                  0
# 3       live free vote blue  veto sununu  veto sununu                   1
# 4                trump is your president 12 more years                  0
# 5    great job governor sununu you have our support...                  0
# 6    thats because the rest of them want us to be t...                  0
# 7    pretty sure the other things tied to that bill...                  0
# 8    joe biden and kamala harris will bring this co...                  1
# 9    sununu leads from behind he waits as long as h...                  1
# 10   sununu gives all healthcare workers 300 weekly...                  0
# 11   joe robbins you need sensible hammer control t...                  0
# 12   ok raise the minimum wage and your property ta...                  0
# 13   lol no thanks  clearly the article is written ...                  0
# 14   what a load of crap  if it were not for sununu...                  0
# 15   sue reinold nh has 2 us senators 2 representat...                  0
# 16   elizabeth crocker moseley obama built those ca...                  0
# 17                               fuck biden and harris                  0
# 18   the biggest danger to the unied states citizen...                  0
# 19   trump trump trump and more trump  thank god fo...                  0
# 20   youre saying my claim is bullshit  so youre te...                  0
# 21   hes done more for me than shaheen and her coho...                  0
# 22   i have contacted numerous people to volunteer ...                  1
# 23   know thine enemy so this is where all the libe...                  0
# 24   trump trumplet sleepy joe go back to bed and t...                  0
# 25   youre proving my point thanks funny how many r...                  1
# 26                                              byedon                  0
# 27    im going to say that some of you need to go b...                  0
# 28   keith macmaster theyre only prochoice when it ...                  0
# 29                                go fuck off demtards                  0
# ..                                                 ...                ...
# 613  at least he has an agenda other than raising t...                  0
# 614   fuck the dems they are killing the usa dems a...                  0
# 615  vetosununu whoever is closest to sununu could ...                  1
# 616  as i hope that no employer is still paying min...                  0
# 617                                        trump  2020                  0
# 618              not watching working to elect nh dems                  1
# 619  what you meant to say was sanunu doesnt feel s...                  0
# 620  you people obviously know nothing about nh or ...                  0
# 621  dump trump and his turd sununu he is a trumpst...                  1
# 622  funny how riots and protests are just fine and...                  0
# 623  joe robbins everyone should be able to dream y...                  0
# 624  no shit he is ugh  theyre getting stolen like ...                  1
# 625  matt worcester obviously those that attended w...                  1
# 626                         hes got to go vote him out                  1
# 627   fuck you sununu and im not voting for you eve...                  1
# 628                most dems are delusional it appears                  0
# 629                                     democrats suck                  0
# 630                                         trump 2020                  0
# 631       just another carpetbagger sent here by trump                  1
# 632   chris sununu 2020  trumppence 2020 all red 2020                   0
# 633  paul bresnahan nthere is no information to val...                  0
# 634                       trump 2020 4 another 4 years                  0
# 635                                    vote republican                  0
# 636                we need republicans not democratic                   0
# 637                                    bidenharris2020                  1
# 638  sununu is a godamn hypocrite as well as a turn...                  1
# 639  most students attend school in only one school...                  0
# 640  dont vote for him wear mask save lives just an...                  1
# 641  burn them no room trump has all the realistate...                  0
# 642  he met trump without a mask after issuing a 10...                  1
#
# [643 rows x 3 columns]

# %%
#counts frequency of republicans and democrats using each n-gram
def freq(x, party_aff):
    rule = x['Terms']
    sum_freq = 0
    
    found_rules = list(users_df[users_df['Message'].str.contains(rule)].index)

    #iterates through all indices of entries containing n-gram
    for i in found_rules:
        message = users_df['Message'][i]
        user_aff = users_df['Party_Affiliation'][i]
        tot_rule = message.count(rule)
        tot = 0

        if party_aff == user_aff:
            tot = tot_rule
                
        sum_freq += tot

        
    return sum_freq

# %%
rules_df['Republican Usage'] = rules_df.apply(freq, args = (0,), axis = 1)
rules_df['Democrat Usage'] = rules_df.apply(freq, args = (1,), axis = 1)

# %%
rules_df
# Out:
#                     Terms  Exceptions  Republican Usage  Democrat Usage
# 0        the minimum wage         NaN                12              10
# 1             a great job         NaN                15               4
# 2              has done a         NaN                18               4
# 3              go back to         NaN                18              12
# 4                a lot of         NaN                 5               8
# 5            vote for him         NaN                 6              10
# 6            vote him out         NaN                 1              24
# 7             he has done         NaN                 8               4
# 8             needs to go         NaN                 4               7
# 9              one of the         NaN                20               2
# 10           done a great         NaN                 8               1
# 11       done a great job         NaN                 8               1
# 12            to vote for         NaN                 5               8
# 13            you want to         NaN                13               9
# 14             a good job         NaN                 9               4
# 15            he needs to         NaN                 3               9
# 16            sununu is a         NaN                 7               5
# 17            the rest of         NaN                10               7
# 18        sununu has done         NaN                 8               1
# 19       of new hampshire         NaN                 9               5
# 20            is going to         NaN                10               6
# 21           dont want to         NaN                 9               2
# 22            if you want         NaN                12              10
# 23       has done a great         NaN                 6               1
# 24            you need to         NaN                 7               6
# 25       in new hampshire         NaN                 2               5
# 26   has done a great job         NaN                 6               1
# 27             get rid of         NaN                 6               8
# 28            if you dont         NaN                15               5
# 29             we need to         NaN                 8              13
# ..                    ...         ...               ...             ...
# 400         you have said         NaN                 0               0
# 401           care of the         NaN                 1               1
# 402           to keep the         NaN                 1               2
# 403          to deal with         NaN                 3               1
# 404       red all the way         NaN                 5               0
# 405          a better job         NaN                 2               0
# 406            trump in a         NaN                 0               0
# 407        gave himself a         NaN                 1               1
# 408      sununu and trump         NaN                10               1
# 409         im not voting         NaN                 0               2
# 410       you can request         NaN                 0               1
# 411   i will not vote for         NaN                 0               4
# 412        they dont want         NaN                 1               1
# 413  in the united states         NaN                 2               0
# 414             get a job         NaN                 1               0
# 415           red all the         NaN                 5               0
# 416          think he has         NaN                 2               1
# 417  done a fantastic job         NaN                 1               0
# 418       i will not vote         NaN                 1               4
# 419         in the united         NaN                 2               0
# 420     will not vote for         NaN                 0               5
# 421       one of the best         NaN                 0               0
# 422         and thats why         NaN                 2               1
# 423           dont have a         NaN                 3               2
# 424       to vote for him         NaN                 0               3
# 425           did you get         NaN                 1               2
# 426         to get rid of         NaN                 3               2
# 427     going to vote for         NaN                 1               2
# 428         no matter who         NaN                 0               0
# 429         trump and the         NaN                 0               1
#
# [430 rows x 4 columns]

# %%
#determines total times n-gram was used in dataset
def tot_usage(x):
    rep = x['Republican Usage']
    dem = x['Democrat Usage']
    
    return rep + dem

# %%
rules_df['Total Usage'] = rules_df.apply(tot_usage, axis = 1)

# %%
rules_df
# Out:
#                     Terms  Exceptions  Republican Usage  Democrat Usage  \
# 0        the minimum wage         NaN                12              10
# 1             a great job         NaN                15               4
# 2              has done a         NaN                18               4
# 3              go back to         NaN                18              12
# 4                a lot of         NaN                 5               8
# 5            vote for him         NaN                 6              10
# 6            vote him out         NaN                 1              24
# 7             he has done         NaN                 8               4
# 8             needs to go         NaN                 4               7
# 9              one of the         NaN                20               2
# 10           done a great         NaN                 8               1
# 11       done a great job         NaN                 8               1
# 12            to vote for         NaN                 5               8
# 13            you want to         NaN                13               9
# 14             a good job         NaN                 9               4
# 15            he needs to         NaN                 3               9
# 16            sununu is a         NaN                 7               5
# 17            the rest of         NaN                10               7
# 18        sununu has done         NaN                 8               1
# 19       of new hampshire         NaN                 9               5
# 20            is going to         NaN                10               6
# 21           dont want to         NaN                 9               2
# 22            if you want         NaN                12              10
# 23       has done a great         NaN                 6               1
# 24            you need to         NaN                 7               6
# 25       in new hampshire         NaN                 2               5
# 26   has done a great job         NaN                 6               1
# 27             get rid of         NaN                 6               8
# 28            if you dont         NaN                15               5
# 29             we need to         NaN                 8              13
# ..                    ...         ...               ...             ...
# 400         you have said         NaN                 0               0
# 401           care of the         NaN                 1               1
# 402           to keep the         NaN                 1               2
# 403          to deal with         NaN                 3               1
# 404       red all the way         NaN                 5               0
# 405          a better job         NaN                 2               0
# 406            trump in a         NaN                 0               0
# 407        gave himself a         NaN                 1               1
# 408      sununu and trump         NaN                10               1
# 409         im not voting         NaN                 0               2
# 410       you can request         NaN                 0               1
# 411   i will not vote for         NaN                 0               4
# 412        they dont want         NaN                 1               1
# 413  in the united states         NaN                 2               0
# 414             get a job         NaN                 1               0
# 415           red all the         NaN                 5               0
# 416          think he has         NaN                 2               1
# 417  done a fantastic job         NaN                 1               0
# 418       i will not vote         NaN                 1               4
# 419         in the united         NaN                 2               0
# 420     will not vote for         NaN                 0               5
# 421       one of the best         NaN                 0               0
# 422         and thats why         NaN                 2               1
# 423           dont have a         NaN                 3               2
# 424       to vote for him         NaN                 0               3
# 425           did you get         NaN                 1               2
# 426         to get rid of         NaN                 3               2
# 427     going to vote for         NaN                 1               2
# 428         no matter who         NaN                 0               0
# 429         trump and the         NaN                 0               1
#
#      Total Usage
# 0             22
# 1             19
# 2             22
# 3             30
# 4             13
# 5             16
# 6             25
# 7             12
# 8             11
# 9             22
# 10             9
# 11             9
# 12            13
# 13            22
# 14            13
# 15            12
# 16            12
# 17            17
# 18             9
# 19            14
# 20            16
# 21            11
# 22            22
# 23             7
# 24            13
# 25             7
# 26             7
# 27            14
# 28            20
# 29            21
# ..           ...
# 400            0
# 401            2
# 402            3
# 403            4
# 404            5
# 405            2
# 406            0
# 407            2
# 408           11
# 409            2
# 410            1
# 411            4
# 412            2
# 413            2
# 414            1
# 415            5
# 416            3
# 417            1
# 418            5
# 419            2
# 420            5
# 421            0
# 422            3
# 423            5
# 424            3
# 425            3
# 426            5
# 427            3
# 428            0
# 429            1
#
# [430 rows x 5 columns]

# %% [markdown]
# # N-Gram Analysis

# %%
#determines n-gram's affiliation
def aff(x):
    rep = x['Republican Usage']
    dem = x['Democrat Usage']
    
    if rep > dem:
        return 0
    elif dem > rep:
        return 1
    else:
        return None

# %%
rules_df['Affiliation'] = rules_df.apply(aff, axis = 1)

# %%
#calculates n-gram's accuracy as a percentage
def percentage(x):
    rep = x['Republican Usage']
    dem = x['Democrat Usage']
    tot = x['Total Usage']    

    if rep > dem:
        percentage = (rep / tot) * 100
        
    elif dem > rep:
        percentage = (dem / tot) * 100

    elif rep == dem & rep != 0:
        percentage = 50    
    else:
        percentage = None

        
    if percentage != None:
        percentage = float('{0:.2f}'.format(percentage))
        
    
    return percentage

# %%
rules_df['Accuracy %'] = rules_df.apply(percentage, axis=1)

# %%
rules_df = rules_df.sort_values(['Total Usage'], ascending = False)

# %%
rules_df
# Out:
#                      Terms  Exceptions  Republican Usage  Democrat Usage  \
# 3               go back to         NaN                18              12
# 6             vote him out         NaN                 1              24
# 0         the minimum wage         NaN                12              10
# 13             you want to         NaN                13               9
# 2               has done a         NaN                18               4
# 22             if you want         NaN                12              10
# 9               one of the         NaN                20               2
# 52        live free or die         NaN                16               5
# 39             free or die         NaN                16               5
# 29              we need to         NaN                 8              13
# 43            live free or         NaN                16               5
# 89              vote for a         NaN                17               3
# 110               to get a         NaN                17               3
# 28             if you dont         NaN                15               5
# 1              a great job         NaN                15               4
# 212          im voting for         NaN                17               0
# 38             all the way         NaN                15               2
# 17             the rest of         NaN                10               7
# 35                to go to         NaN                 7               9
# 5             vote for him         NaN                 6              10
# 20             is going to         NaN                10               6
# 70              trump is a         NaN                 5              10
# 40            do you think         NaN                 9               5
# 19        of new hampshire         NaN                 9               5
# 27              get rid of         NaN                 6               8
# 65    the democratic party         NaN                11               3
# 47            i dont think         NaN                10               4
# 88           trump and his         NaN                 4              10
# 32              be able to         NaN                10               4
# 312     the democrat party         NaN                12               1
# ..                     ...         ...               ...             ...
# 336     when you heard him         NaN                 0               0
# 333          he did a good         NaN                 0               0
# 330             but i dont         NaN                 0               0
# 328          more money to         NaN                 0               0
# 353      just lost my vote         NaN                 0               0
# 354            want to pay         NaN                 0               0
# 326      he did a good job         NaN                 0               0
# 325        is a republican         NaN                 0               0
# 324         whats best for         NaN                 0               0
# 358         of the country         NaN                 0               0
# 321             go to work         NaN                 0               0
# 320         he turned down         NaN                 0               0
# 314   he doesnt care about         NaN                 0               0
# 313            a couple of         NaN                 0               0
# 311           will go away         NaN                 0               0
# 310          their kids to         NaN                 0               0
# 305  down the minimum wage         NaN                 0               0
# 372   would never vote for         NaN                 0               0
# 295      are talking about         NaN                 0               0
# 289          wont vote for         NaN                 0               0
# 286       the internet and         NaN                 0               0
# 284           vote for you         NaN                 0               0
# 383        you are talking         NaN                 0               0
# 385         good luck with         NaN                 0               0
# 386      and you have said         NaN                 0               0
# 342         when you heard         NaN                 0               0
# 274        send their kids         NaN                 0               0
# 263             have to go         NaN                 0               0
# 392           just lost my         NaN                 0               0
# 215        turned down the         NaN                 0               0
#
#      Total Usage  Affiliation  Accuracy %
# 3             30          0.0       60.00
# 6             25          1.0       96.00
# 0             22          0.0       54.55
# 13            22          0.0       59.09
# 2             22          0.0       81.82
# 22            22          0.0       54.55
# 9             22          0.0       90.91
# 52            21          0.0       76.19
# 39            21          0.0       76.19
# 29            21          1.0       61.90
# 43            21          0.0       76.19
# 89            20          0.0       85.00
# 110           20          0.0       85.00
# 28            20          0.0       75.00
# 1             19          0.0       78.95
# 212           17          0.0      100.00
# 38            17          0.0       88.24
# 17            17          0.0       58.82
# 35            16          1.0       56.25
# 5             16          1.0       62.50
# 20            16          0.0       62.50
# 70            15          1.0       66.67
# 40            14          0.0       64.29
# 19            14          0.0       64.29
# 27            14          1.0       57.14
# 65            14          0.0       78.57
# 47            14          0.0       71.43
# 88            14          1.0       71.43
# 32            14          0.0       71.43
# 312           13          0.0       92.31
# ..           ...          ...         ...
# 336            0          NaN         NaN
# 333            0          NaN         NaN
# 330            0          NaN         NaN
# 328            0          NaN         NaN
# 353            0          NaN         NaN
# 354            0          NaN         NaN
# 326            0          NaN         NaN
# 325            0          NaN         NaN
# 324            0          NaN         NaN
# 358            0          NaN         NaN
# 321            0          NaN         NaN
# 320            0          NaN         NaN
# 314            0          NaN         NaN
# 313            0          NaN         NaN
# 311            0          NaN         NaN
# 310            0          NaN         NaN
# 305            0          NaN         NaN
# 372            0          NaN         NaN
# 295            0          NaN         NaN
# 289            0          NaN         NaN
# 286            0          NaN         NaN
# 284            0          NaN         NaN
# 383            0          NaN         NaN
# 385            0          NaN         NaN
# 386            0          NaN         NaN
# 342            0          NaN         NaN
# 274            0          NaN         NaN
# 263            0          NaN         NaN
# 392            0          NaN         NaN
# 215            0          NaN         NaN
#
# [430 rows x 7 columns]

# %% [markdown]
# # Export N-Grams Analysis Data

# %%
rules_df.to_csv('N-Gram Analysis.csv')
